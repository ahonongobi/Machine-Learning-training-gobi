# %%
! pip install sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sklearn
#   Downloading sklearn-0.0.post7.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post7-py3-none-any.whl size=2360 sha256=8023540413e6cb1450517c1053382759c3dea5f2ae55cf1d8fbadcaae5bb231c
#   Stored in directory: /home/gobi/.cache/pip/wheels/c8/9c/85/72901eb50bc4bc6e3b2629378d172384ea3dfd19759c77fd2c
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0.post7
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 6
#       4 import numpy as np
#       5 import pandas as pd
# ----> 6 from sklearn import datasets, linear_model
#       7 from sklearn.metrics import mean_squared_error, r2_score
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
diabetes = datasets.load_diabetes()

# %%
## print(diabetes['DESCR'])

# %%
predictors = diabetes['data']
target = diabetes['target']

# %%
target.shape
# Out:
# (442,)

# %%
# 2eme facon pour acceder aux donnees
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True, as_frame=True)

# %%
diabetes_y.shape
# Out:
# (442,)

# %%
diabetes_X.head(10)
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5 -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6 -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7  0.063504  0.050680 -0.001895  0.066629  0.090620  0.108914  0.022869
# 8  0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 9 -0.070900 -0.044642  0.039062 -0.033213 -0.012577 -0.034508 -0.024993
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641
# 5 -0.076395 -0.041176 -0.096346
# 6 -0.039493 -0.062917 -0.038357
# 7  0.017703 -0.035816  0.003064
# 8 -0.002592 -0.014960  0.011349
# 9 -0.002592  0.067737 -0.013504

# %%
diabetes_y.head(10)
# Out:
# 0    151.0
# 1     75.0
# 2    141.0
# 3    206.0
# 4    135.0
# 5     97.0
# 6    138.0
# 7     63.0
# 8    110.0
# 9    310.0
# Name: target, dtype: float64

# %%
diabetes_y.columns = ['Disease progression']

# %%
diabetes_y.columns
# Out:
# ['Disease progression']

# %% [markdown]
# #### EDA

# %%
diabetes_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %%
diabetes_y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 442 entries, 0 to 441
# Series name: target
# Non-Null Count  Dtype
# --------------  -----
# 442 non-null    float64
# dtypes: float64(1)
# memory usage: 3.6 KB

# %%
diabetes_X.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260971e-01 -1.377672e-01
# 25%   -3.035840e-02 -3.511716e-02 -3.949338e-02 -3.324559e-02 -3.317903e-02
# 50%   -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947171e-03 -1.077698e-03
# 75%    2.984439e-02  2.931150e-02  3.430886e-02  3.243232e-02  2.791705e-02
# max    1.987880e-01  1.811791e-01  1.852344e-01  1.335973e-01  1.356118e-01

# %%
diabetes_X.duplicated().sum()
# Out:
# 0

# %%
diabetes_X['sex'].unique()
# Out:
# array([ 0.05068012, -0.04464164])

# %%
diabetes_X.boxplot()
# Out:
# <AxesSubplot:>

# %%
for i in range(8):
    feature = pd.DataFrame(diabetes_X.iloc[:,i])
    plt.scatter(feature, diabetes_y, s=1)
    plt.xlabel(diabetes_X.columns.values[i])
    plt.ylabel('target')
    plt.tight_layout()
    plt.show()

# %%
sns.heatmap(diabetes_X.corr())
# Out:
# <AxesSubplot:>

# %%
# Il n' y a pas de correlation entre sex et le label, donc on le remove
diabetes_X.drop(['sex', 'age'], axis=1,inplace=True)

# %%
diabetes_X.columns
# Out:
# Index(['bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6'], dtype='object')

# %%
# Diviser les donnees entre apprentissage et test
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(diabetes_X, diabetes_y, test_size=0.3, random_state=42)

# %%
# On cree un objet du model
regr = linear_model.LinearRegression()

# %%
# Entraînez le modèle à l'aide des ensembles d'entraînement
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Faire des prédictions à l'aide de l'ensemble de test
diabetes_y_pred = regr.predict(X_test)

# %%
diabetes_y_pred
# Out:
# array([128.90702757, 169.95246924, 146.45016118, 265.10454477,
#        133.33715556,  85.76375432, 275.78273428, 195.8435415 ,
#         98.71264745, 127.17805184,  89.18027263, 149.96880462,
#         51.60673064, 212.75436282, 111.46230447, 145.07637203,
#        228.5175945 , 256.80458822, 208.87953591, 227.40020784,
#        198.13518587,  78.03265368,  64.12879879, 198.66798437,
#        152.49306523, 170.00210111, 202.11403156, 184.28915736,
#         43.87249126, 121.4265748 , 168.09514027,  81.10238755,
#        145.35756488, 189.14583181, 159.60962305, 211.89628315,
#        133.94839178, 128.94214021, 151.65372378,  51.35593714,
#         62.46992536, 120.93044697, 171.57335811, 152.96348124,
#        156.1590175 ,  58.56414068,  67.37795246, 104.36299289,
#         43.90221458, 157.8287804 , 149.70218753,  57.73458358,
#        114.20326904,  99.26202361, 182.42873284, 153.55103788,
#         84.99647183, 221.30718389, 113.58802663,  70.44664142,
#        175.85750238, 195.82393612, 160.22936557, 118.84743227,
#        114.24605189, 191.0431918 , 179.56056708, 172.38468839,
#        116.96805806, 154.41772652, 189.28572488, 206.85822428,
#        210.56404566, 156.25387237,  68.42498139, 159.01515155,
#        207.88137911, 198.42943647, 170.58113028, 182.21565357,
#        105.69133238, 133.70747413,  48.61066575,  50.86078769,
#        103.21631713,  74.20472517,  73.367794  ,  45.84368472,
#        159.65997359, 191.90680055, 155.38139659, 228.52835533,
#         97.35604462,  58.37153098,  48.89748167, 184.95851843,
#        259.10160577, 172.8069254 , 101.89120505,  52.86769047,
#        203.4522456 , 107.40905542, 281.45572123, 106.52456012,
#        161.99493152,  99.93544501, 137.15732603, 132.39151346,
#        162.4463181 , 171.80813435, 115.90924623, 200.91396701,
#        183.77720731, 200.7568576 , 202.55231626, 149.52994826,
#        136.28853943, 146.40996141, 109.4150802 , 157.4018305 ,
#        162.67208926,  85.97655053,  58.24775505, 178.42805037,
#        134.93252956, 194.06579475, 156.98032376, 118.69988265,
#        200.79781614,  84.917345  , 132.02576302,  76.47261689,
#        239.86871961])

# %%
# Les coefficients
print("Coefficients: \n", regr.coef_)
# Le mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, diabetes_y_pred))
# Le coefficient of determination: 1 est une prediction perfecte
print("Coefficient de determination: %.2f" % r2_score(y_test, diabetes_y_pred))
# Out:
# Coefficients:
#  [ 594.11309516  342.91763026 -819.82590898  471.84005726  137.40045262
#   181.31779167  675.11160145   34.43533325]
# Mean squared error: 2871.19
# Coefficient of determination: 0.47

# %%
diabetes_X.columns
# Out:
# Index(['bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6'], dtype='object')

# %%
plt.scatter(diabetes_y_pred,y_test, color="black")
plt.xlabel('Valeurs predictes')
plt.ylabel('valeurs reels')
plt.xticks(())
plt.yticks(())

plt.show()
